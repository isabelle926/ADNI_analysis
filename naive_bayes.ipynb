# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('DTI_with_group.csv')
# remove unnecessary columns + confounding
df = df.drop(['IMAGEUID', 'COLPROT', 'RID', 'VISCODE', 
                          'VISCODE2', 'EXAMDATE', 'VERSION', 'MANUFACTURER',
                         'RUNDATE', 'STATUS', 'QC', 'update_stamp', 'Age', 'VOLUMES', 'Sex'], axis=1)
# remove rows with empty values
df = df.dropna()
df
# Out:
#        AD_MCP    AD_PCT    AD_GCC    AD_BCC    AD_SCC     AD_FX  AD_CST_R  \
# 0    0.001177  0.000974  0.001479  0.001474  0.001575  0.002257  0.001079
# 2    0.001213  0.001075  0.001567  0.001585  0.001686  0.002492  0.001046
# 3    0.001101  0.000965  0.001440  0.001433  0.001456  0.002379  0.000985
# 4    0.001053  0.000904  0.001433  0.001470  0.001450  0.002421  0.000966
# 5    0.001131  0.000974  0.001469  0.001498  0.001531  0.002291  0.000994
# ..        ...       ...       ...       ...       ...       ...       ...
# 963  0.001117  0.001011  0.001574  0.001646  0.001712  0.002214  0.001094
# 964  0.001181  0.001002  0.001423  0.001505  0.001530  0.002266  0.001088
# 965  0.001126  0.000949  0.001542  0.001747  0.001642  0.002565  0.000978
# 966  0.001090  0.000976  0.001354  0.001421  0.001427  0.001928  0.001018
# 967  0.001097  0.000984  0.001477  0.001419  0.001502  0.002556  0.001063
#
#      AD_CST_L   AD_ML_R   AD_ML_L  ...   RD_FXST    RD_SLF    RD_SFO  \
# ...

# %%
X = df.iloc[:, df.columns != 'Research Group'].values
y = df.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=8)

# %%
from sklearn.naive_bayes import GaussianNB

# Build a Gaussian Classifier
model = GaussianNB()

# Model training
model.fit(X_train, y_train)

# Predict Output
predicted = model.predict([X_test[6]])

print("Actual Value:", y_test[6])
print("Predicted Value:", predicted[0])
# Out:
# Actual Value: CN
# Predicted Value: SMC

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
)

y_pred = model.predict(X_test)
accuray = accuracy_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test, average="weighted")

print("Accuracy:", accuray)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.1525974025974026
# F1 Score: 0.12365111263166295

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 5,  0,  0,  1,  0,  7],
#        [21, 23, 13, 11, 18, 88],
#        [13,  4,  5,  0,  2, 10],
#        [ 5,  2,  0,  3,  0, 11],
#        [11,  3,  6,  4,  4, 24],
#        [ 1,  0,  4,  1,  1,  7]])

# %% [markdown]
# # Combined MCI Groups

# %%
new_df = pd.read_csv('DTI_with_group_comb.csv')
# remove unnecessary columns + confounding
new_df = new_df.drop(['IMAGEUID', 'COLPROT', 'RID', 'VISCODE', 
                          'VISCODE2', 'EXAMDATE', 'VERSION', 'MANUFACTURER',
                         'RUNDATE', 'STATUS', 'QC', 'update_stamp', 'Age', 'VOLUMES', 'Sex'], axis=1)
# remove rows with empty values
new_df = new_df.dropna()
new_df
# Out:
#        AD_MCP    AD_PCT    AD_GCC    AD_BCC    AD_SCC     AD_FX  AD_CST_R  \
# 0    0.001177  0.000974  0.001479  0.001474  0.001575  0.002257  0.001079
# 2    0.001213  0.001075  0.001567  0.001585  0.001686  0.002492  0.001046
# 3    0.001101  0.000965  0.001440  0.001433  0.001456  0.002379  0.000985
# 4    0.001053  0.000904  0.001433  0.001470  0.001450  0.002421  0.000966
# 5    0.001131  0.000974  0.001469  0.001498  0.001531  0.002291  0.000994
# ..        ...       ...       ...       ...       ...       ...       ...
# 963  0.001117  0.001011  0.001574  0.001646  0.001712  0.002214  0.001094
# 964  0.001181  0.001002  0.001423  0.001505  0.001530  0.002266  0.001088
# 965  0.001126  0.000949  0.001542  0.001747  0.001642  0.002565  0.000978
# 966  0.001090  0.000976  0.001354  0.001421  0.001427  0.001928  0.001018
# 967  0.001097  0.000984  0.001477  0.001419  0.001502  0.002556  0.001063
#
#      AD_CST_L   AD_ML_R   AD_ML_L  ...   RD_FXST    RD_SLF    RD_SFO  \
# ...

# %%
new_X = new_df.iloc[:, new_df.columns != 'Research Group'].values
new_y = new_df.iloc[:, -1].values

# %%
new_X_train, new_X_test, new_y_train, new_y_test = train_test_split(new_X, new_y, test_size=0.33, random_state=6)

# %%
# Build a Gaussian Classifier
model = GaussianNB()

# Model training
model.fit(new_X_train, new_y_train)

# Predict Output
predicted = model.predict([new_X_test[6]])

print("Actual Value:", new_y_test[6])
print("Predicted Value:", predicted[0])
# Out:
# Actual Value: MCI
# Predicted Value: CN

# %%
new_y_pred = model.predict(new_X_test)
accuracy = accuracy_score(new_y_pred, new_y_test)
f1 = f1_score(new_y_pred, new_y_test, average="weighted")

print("Accuracy:", accuracy)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.5422077922077922
# F1 Score: 0.5389490261424064

# %%
cm = confusion_matrix(new_y_test, new_y_pred)
cm
# Out:
# array([[  3,   7,   1],
#        [ 29, 148,  23],
#        [ 26,  55,  16]])
