# %%
# import packages and read csv
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import export_graphviz
import pydot
import matplotlib.pyplot as plt

features = pd.read_csv('DTI_with_group.csv')
features.head(5)
# Out:
#    IMAGEUID COLPROT  RID VISCODE VISCODE2  EXAMDATE  VERSION MANUFACTURER  \
# 0    957753   ADNI3   21    init     m144   1/25/18      2.0      Siemens
# 1    987377   ADNI3   31    init     m150   4/17/18      NaN      Siemens
# 2   1158142   ADNI3   31      y1     m162   4/24/19      2.0      Siemens
# 3   1116459   ADNI3   56      y1     m156   1/10/19      2.0      Siemens
# 4   1189755   ADNI3   56    init     m144  11/28/17      2.0      Siemens
#
#    VOLUMES  RUNDATE  ...    RD_UNC    RD_TAP     RD_IC     RD_CC     RD_CR  \
# 0       55  12/1/21  ...  0.000600  0.001139  0.000491  0.000562  0.000638
# 1      127  12/1/21  ...       NaN       NaN       NaN       NaN       NaN
# 2      127  12/1/21  ...  0.000717  0.001507  0.000626  0.000701  0.000851
# 3      127  12/1/21  ...  0.000553  0.000950  0.000448  0.000512  0.000587
# 4      127  12/1/21  ...  0.000530  0.000862  0.000437  0.000509  0.000573
#
#    RD_FULLWM  update_stamp  Sex  Research Group   Age
# 0   0.000571           NaN    F              CN  84.9
# 1        NaN           NaN    F              CN  90.3
# 2   0.000723           NaN    F              CN  91.3
# 3   0.000531           NaN    F              CN  82.8
# 4   0.000522           NaN    F              CN  81.7
#
# [5 rows x 308 columns]

# %%
features.describe()
# Out:
#            IMAGEUID          RID  VERSION     VOLUMES      AD_MCP      AD_PCT  \
# count  9.680000e+02   968.000000    934.0  968.000000  933.000000  933.000000
# mean   1.019289e+06  5138.766529      2.0   62.929752    0.001077    0.000982
# std    1.102226e+05  1763.616817      0.0   34.340940    0.000060    0.000077
# min    8.088260e+05    21.000000      2.0   31.000000    0.000829    0.000679
# 25%    9.353970e+05  4394.250000      2.0   36.000000    0.001046    0.000939
# 50%    1.005818e+06  6066.500000      2.0   55.000000    0.001082    0.000990
# 75%    1.099537e+06  6370.250000      2.0   55.000000    0.001116    0.001033
# max    1.332415e+06  6832.000000      2.0  127.000000    0.001266    0.001214
#
#            AD_GCC      AD_BCC      AD_SCC       AD_FX  ...      RD_SLF  \
# count  933.000000  933.000000  933.000000  933.000000  ...  933.000000
# mean     0.001447    0.001502    0.001544    0.002359  ...    0.000560
# std      0.000073    0.000081    0.000088    0.000246  ...    0.000042
# min      0.001210    0.001214    0.001234    0.001629  ...    0.000443
# 25%      0.001404    0.001447    0.001496    0.002186  ...    0.000534
# 50%      0.001448    0.001498    0.001547    0.002349  ...    0.000556
# 75%      0.001491    0.001551    0.001601    0.002503  ...    0.000582
# max      0.001666    0.001790    0.001807    0.003424  ...    0.000855
#
#            RD_SFO      RD_UNC      RD_TAP       RD_IC       RD_CC       RD_CR  \
# count  933.000000  933.000000  933.000000  933.000000  933.000000  933.000000
# mean     0.000634    0.000611    0.001142    0.000477    0.000548    0.000615
# std      0.000106    0.000058    0.000233    0.000039    0.000074    0.000057
# min      0.000460    0.000441    0.000625    0.000350    0.000373    0.000502
# 25%      0.000561    0.000573    0.000979    0.000452    0.000497    0.000577
# 50%      0.000610    0.000602    0.001117    0.000473    0.000536    0.000604
# 75%      0.000683    0.000641    0.001282    0.000499    0.000595    0.000642
# max      0.001140    0.000892    0.001913    0.000659    0.000836    0.001018
#
#         RD_FULLWM  update_stamp         Age
# count  933.000000           0.0  968.000000
# mean     0.000562           NaN   74.619731
# std      0.000044           NaN    7.880330
# min      0.000430           NaN   55.100000
# 25%      0.000533           NaN   69.000000
# 50%      0.000557           NaN   74.150000
# 75%      0.000586           NaN   80.600000
# max      0.000772           NaN   95.900000
#
# [8 rows x 298 columns]

# %%
# remove unnecessary columns
features = features.drop(['IMAGEUID', 'COLPROT', 'RID', 'VISCODE', 
                          'VISCODE2', 'EXAMDATE', 'VERSION', 'MANUFACTURER',
                         'RUNDATE', 'STATUS', 'QC', 'update_stamp'], axis=1)

# remove rows with empty values
features = features.dropna()

features.head(5)
# Out:
#    VOLUMES    AD_MCP    AD_PCT    AD_GCC    AD_BCC    AD_SCC     AD_FX  \
# 0       55  0.001177  0.000974  0.001479  0.001474  0.001575  0.002257
# 2      127  0.001213  0.001075  0.001567  0.001585  0.001686  0.002492
# 3      127  0.001101  0.000965  0.001440  0.001433  0.001456  0.002379
# 4      127  0.001053  0.000904  0.001433  0.001470  0.001450  0.002421
# 5      127  0.001131  0.000974  0.001469  0.001498  0.001531  0.002291
#
#    AD_CST_R  AD_CST_L   AD_ML_R  ...    RD_SFO    RD_UNC    RD_TAP     RD_IC  \
# 0  0.001079  0.001081  0.001285  ...  0.000551  0.000600  0.001139  0.000491
# 2  0.001046  0.001056  0.001149  ...  0.000902  0.000717  0.001507  0.000626
# 3  0.000985  0.000990  0.001118  ...  0.000562  0.000553  0.000950  0.000448
# 4  0.000966  0.000977  0.001047  ...  0.000551  0.000530  0.000862  0.000437
# 5  0.000994  0.001017  0.001128  ...  0.000586  0.000558  0.000901  0.000458
#
#       RD_CC     RD_CR  RD_FULLWM  Sex  Research Group   Age
# 0  0.000562  0.000638   0.000571    F              CN  84.9
# 2  0.000701  0.000851   0.000723    F              CN  91.3
# 3  0.000512  0.000587   0.000531    F              CN  82.8
# 4  0.000509  0.000573   0.000522    F              CN  81.7
# 5  0.000527  0.000605   0.000545    F              CN  83.7
#
# [5 rows x 296 columns]

# %%
labels = np.array(features['Research Group'])
labels = pd.get_dummies(labels)
features = features.drop('Research Group', axis=1)

# one-hot encode
features = pd.get_dummies(features)

feature_list = list(features.columns)
features = np.array(features)

# %%
# split dataset into training and testing
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size=0.2, random_state=53)

# %%
from sklearn.ensemble import RandomForestRegressor

# instantiate model with decision trees
rf = RandomForestRegressor(n_estimators = 6000, random_state = 53)

# Train the model on training data
rf.fit(train_features, train_labels);

# %%
predictions = rf.predict(test_features)
errors = abs(predictions - test_labels)
print('Mean Absolute Error:', round(np.mean(errors), 5))
# Out:
# Mean Absolute Error: 0.20421

# %%
mape = 100 * (errors / test_labels)
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 5), '%.')
# Out:
# Accuracy: -inf %.

# %%
# get numerical features importance
importances = list(rf.feature_importances_)

# list of tuples with variance and importance
feature_importances = [(feature, round(importance, 5)) for feature, importance in zip(feature_list, importances)]

# sort features importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# print out features and importances
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: Age                  Importance: 0.01593
# Variable: AD_GCC               Importance: 0.01031
# Variable: FA_FX                Importance: 0.01004
# Variable: FA_SCC               Importance: 0.00851
# Variable: MD_CGH_R             Importance: 0.00844
# Variable: RD_CGH_R             Importance: 0.00806
# Variable: RD_CC                Importance: 0.00775
# Variable: RD_SCC               Importance: 0.00737
# Variable: AD_UNC_L             Importance: 0.00727
# Variable: RD_BCC               Importance: 0.00684
# Variable: AD_UNC               Importance: 0.00665
# Variable: AD_SS_L              Importance: 0.00614
# Variable: MD_SCC               Importance: 0.00606
# Variable: AD_SFO_R             Importance: 0.00584
# Variable: AD_SCP_L             Importance: 0.00577
# Variable: MD_UNC_L             Importance: 0.00577
# Variable: AD_ML_L              Importance: 0.00566
# Variable: FA_BCC               Importance: 0.00563
# Variable: AD_FXST_L            Importance: 0.00546
# Variable: FA_PCT               Importance: 0.00538
# Variable: MD_UNC               Importance: 0.00537
# Variable: FA_PTR_L             Importance: 0.00533
# Variable: FA_SCR_R             Importance: 0.00532
# Variable: MD_UNC_R             Importance: 0.00532
# Variable: AD_SCC               Importance: 0.0053
# Variable: FA_ML_L              Importance: 0.00524
# Variable: FA_MCP               Importance: 0.00523
# Variable: FA_SFO_R             Importance: 0.00522
# Variable: AD_SLF_L             Importance: 0.00514
# Variable: FA_PCR_R             Importance: 0.00509
# Variable: RD_UNC_L             Importance: 0.00492
# Variable: FA_CST_L             Importance: 0.00475
# Variable: FA_SS_R              Importance: 0.00473
# Variable: AD_BCC               Importance: 0.00469
# Variable: MD_SCP_R             Importance: 0.00467
# Variable: AD_MCP               Importance: 0.00463
# Variable: AD_CP_L              Importance: 0.00458
# Variable: FA_CST               Importance: 0.00455
# Variable: AD_ACR_R             Importance: 0.0045
# Variable: FA_FXST_L            Importance: 0.0045
# Variable: RD_RLIC_L            Importance: 0.0045
# Variable: RD_FXST_R            Importance: 0.0045
# Variable: RD_PCT               Importance: 0.00447
# Variable: FA_ICP_L             Importance: 0.00446
# Variable: AD_CC                Importance: 0.00442
# Variable: FA_RLIC_R            Importance: 0.00442
# Variable: AD_UNC_R             Importance: 0.00437
# Variable: FA_GCC               Importance: 0.00436
# Variable: AD_FXST              Importance: 0.00435
# Variable: AD_CGC_L             Importance: 0.00431
# Variable: MD_CGH               Importance: 0.00431
# Variable: FA_SLF_L             Importance: 0.00428
# Variable: FA_PCR_L             Importance: 0.00424
# Variable: AD_FXST_R            Importance: 0.00423
# Variable: FA_SCR               Importance: 0.00422
# Variable: AD_PTR_L             Importance: 0.00421
# Variable: FA_SFO_L             Importance: 0.00417
# Variable: MD_SCP               Importance: 0.00414
# Variable: FA_ACR_R             Importance: 0.00413
# Variable: FA_SCP_L             Importance: 0.00412
# Variable: AD_ML_R              Importance: 0.0041
# Variable: AD_SCP_R             Importance: 0.00408
# Variable: FA_CC                Importance: 0.00404
# Variable: RD_FX                Importance: 0.00404
# Variable: FA_SFO               Importance: 0.00403
# Variable: RD_CST_L             Importance: 0.00403
# Variable: AD_RLIC_L            Importance: 0.004
# Variable: AD_ML                Importance: 0.004
# Variable: MD_SCP_L             Importance: 0.00399
# Variable: RD_UNC_R             Importance: 0.00399
# Variable: MD_FXST_R            Importance: 0.00397
# Variable: AD_SCP               Importance: 0.00392
# Variable: AD_PCT               Importance: 0.00391
# Variable: FA_ML                Importance: 0.00389
# Variable: RD_TAP_L             Importance: 0.00386
# Variable: RD_SCP_R             Importance: 0.00383
# Variable: FA_FXST_R            Importance: 0.00381
# Variable: FA_ML_R              Importance: 0.0038
# Variable: FA_RLIC              Importance: 0.0038
# Variable: RD_CGH               Importance: 0.00379
# Variable: RD_CST_R             Importance: 0.00378
# Variable: FA_UNC_L             Importance: 0.00375
# Variable: RD_ICP_L             Importance: 0.00375
# Variable: FA_SCR_L             Importance: 0.00374
# Variable: RD_UNC               Importance: 0.00374
# Variable: FA_CST_R             Importance: 0.00372
# Variable: FA_PCR               Importance: 0.00371
# Variable: FA_FXST              Importance: 0.0037
# Variable: MD_CGH_L             Importance: 0.00368
# Variable: FA_UNC_R             Importance: 0.00366
# Variable: RD_SS_R              Importance: 0.00366
# Variable: MD_MCP               Importance: 0.00365
# Variable: AD_ICP_L             Importance: 0.00359
# Variable: AD_CGH_L             Importance: 0.00359
# Variable: AD_CGC               Importance: 0.00359
# Variable: RD_CGH_L             Importance: 0.00355
# Variable: AD_PTR_R             Importance: 0.00354
# Variable: AD_CGC_R             Importance: 0.00352
# Variable: RD_MCP               Importance: 0.00352
# Variable: RD_ICP_R             Importance: 0.00348
# Variable: RD_ALIC_R            Importance: 0.00346
# Variable: AD_CST_R             Importance: 0.00345
# Variable: AD_EC_L              Importance: 0.00343
# Variable: FA_CP_R              Importance: 0.00343
# Variable: FA_PLIC_R            Importance: 0.00343
# Variable: MD_CST_R             Importance: 0.00341
# Variable: AD_FX                Importance: 0.0034
# Variable: FA_TAP_L             Importance: 0.0034
# Variable: MD_ALIC_R            Importance: 0.00339
# Variable: RD_PCR_L             Importance: 0.00339
# Variable: MD_FX                Importance: 0.00338
# Variable: FA_PTR_R             Importance: 0.00337
# Variable: MD_ML_R              Importance: 0.00337
# Variable: MD_TAP_R             Importance: 0.00337
# Variable: RD_ML_R              Importance: 0.00336
# Variable: RD_SCP_L             Importance: 0.00336
# Variable: MD_RLIC_L            Importance: 0.00333
# Variable: AD_SLF               Importance: 0.00331
# Variable: MD_ICP_L             Importance: 0.0033
# Variable: MD_SLF_L             Importance: 0.00329
# Variable: FA_CGH_L             Importance: 0.00328
# Variable: MD_PCT               Importance: 0.00328
# Variable: AD_CP_R              Importance: 0.00327
# Variable: RD_PTR_L             Importance: 0.00327
# Variable: AD_ACR               Importance: 0.00326
# Variable: MD_PLIC_R            Importance: 0.00326
# Variable: RD_PLIC_R            Importance: 0.00325
# Variable: AD_TAP_L             Importance: 0.00324
# Variable: FA_ACR_L             Importance: 0.00324
# Variable: FA_RLIC_L            Importance: 0.00323
# Variable: AD_CGH_R             Importance: 0.00321
# Variable: FA_CR                Importance: 0.00321
# Variable: MD_CGC_L             Importance: 0.0032
# Variable: AD_SFO               Importance: 0.00319
# Variable: MD_FXST              Importance: 0.00319
# Variable: AD_PCR_L             Importance: 0.00318
# Variable: MD_SS_R              Importance: 0.00318
# Variable: MD_FXST_L            Importance: 0.00315
# Variable: AD_SCR_R             Importance: 0.00314
# Variable: FA_ICP_R             Importance: 0.00314
# Variable: FA_CP_L              Importance: 0.00313
# Variable: AD_RLIC_R            Importance: 0.00312
# Variable: AD_SS                Importance: 0.00312
# Variable: FA_ACR               Importance: 0.00311
# Variable: FA_SLF               Importance: 0.0031
# Variable: RD_SFO_R             Importance: 0.0031
# Variable: MD_CGC_R             Importance: 0.00309
# Variable: RD_SCP               Importance: 0.00309
# Variable: MD_CC                Importance: 0.00307
# Variable: AD_SLF_R             Importance: 0.00306
# Variable: FA_CGH_R             Importance: 0.00306
# Variable: FA_SCP_R             Importance: 0.00304
# Variable: RD_TAP_R             Importance: 0.00303
# Variable: FA_SS_L              Importance: 0.00302
# Variable: AD_PTR               Importance: 0.00299
# Variable: FA_ALIC_R            Importance: 0.00297
# Variable: MD_GCC               Importance: 0.00297
# Variable: MD_BCC               Importance: 0.00297
# Variable: AD_SS_R              Importance: 0.00296
# Variable: FA_SLF_R             Importance: 0.00295
# Variable: AD_PLIC_R            Importance: 0.00292
# Variable: FA_UNC               Importance: 0.00292
# Variable: FA_EC_L              Importance: 0.00289
# Variable: MD_ALIC_L            Importance: 0.00289
# Variable: RD_CST               Importance: 0.00289
# Variable: AD_TAP_R             Importance: 0.00288
# Variable: MD_CP_L              Importance: 0.00288
# Variable: AD_SCR_L             Importance: 0.00287
# Variable: FA_SCP               Importance: 0.00287
# Variable: RD_SLF_L             Importance: 0.00287
# Variable: RD_ML_L              Importance: 0.00286
# Variable: RD_CP_R              Importance: 0.00286
# Variable: FA_TAP_R             Importance: 0.00285
# Variable: RD_CGC_R             Importance: 0.00285
# Variable: FA_TAP               Importance: 0.00284
# Variable: AD_PLIC_L            Importance: 0.00283
# Variable: AD_CGH               Importance: 0.00283
# Variable: FA_ICP               Importance: 0.00281
# Variable: AD_CST               Importance: 0.0028
# Variable: AD_SFO_L             Importance: 0.00279
# Variable: AD_ICP_R             Importance: 0.00277
# Variable: FA_PLIC_L            Importance: 0.00277
# Variable: AD_CST_L             Importance: 0.00276
# Variable: AD_TAP               Importance: 0.00276
# Variable: MD_ML_L              Importance: 0.00276
# Variable: MD_CP_R              Importance: 0.00276
# Variable: MD_PCR_L             Importance: 0.00276
# Variable: RD_CGC_L             Importance: 0.00275
# Variable: FA_EC_R              Importance: 0.00274
# Variable: AD_ACR_L             Importance: 0.00273
# Variable: MD_CST               Importance: 0.00273
# Variable: RD_ML                Importance: 0.00273
# Variable: AD_ALIC_L            Importance: 0.00272
# Variable: FA_PLIC              Importance: 0.00272
# Variable: MD_RLIC_R            Importance: 0.00272
# Variable: FA_CP                Importance: 0.0027
# Variable: RD_GCC               Importance: 0.00269
# Variable: RD_SS_L              Importance: 0.00269
# Variable: RD_FXST_L            Importance: 0.00269
# Variable: AD_CP                Importance: 0.00268
# Variable: RD_SLF_R             Importance: 0.00267
# Variable: AD_PCR_R             Importance: 0.00266
# Variable: MD_TAP_L             Importance: 0.00266
# Variable: MD_ICP_R             Importance: 0.00264
# Variable: RD_CP_L              Importance: 0.00264
# Variable: RD_RLIC_R            Importance: 0.00264
# Variable: RD_SCR_L             Importance: 0.00264
# Variable: FA_CGC_L             Importance: 0.00263
# Variable: MD_CST_L             Importance: 0.00263
# Variable: MD_ALIC              Importance: 0.00263
# Variable: MD_PTR_L             Importance: 0.00262
# Variable: AD_CR                Importance: 0.00261
# Variable: FA_PTR               Importance: 0.00259
# Variable: RD_ICP               Importance: 0.00259
# Variable: RD_SS                Importance: 0.00259
# Variable: MD_SS_L              Importance: 0.00256
# Variable: RD_PLIC_L            Importance: 0.00256
# Variable: AD_ALIC_R            Importance: 0.00253
# Variable: FA_SS                Importance: 0.00253
# Variable: AD_EC                Importance: 0.00251
# Variable: RD_FXST              Importance: 0.00251
# Variable: AD_SCR               Importance: 0.0025
# Variable: FA_CGH               Importance: 0.0025
# Variable: MD_ML                Importance: 0.0025
# Variable: MD_SLF               Importance: 0.0025
# Variable: RD_SCR_R             Importance: 0.0025
# Variable: RD_RLIC              Importance: 0.00248
# Variable: AD_RLIC              Importance: 0.00247
# Variable: AD_EC_R              Importance: 0.00246
# Variable: RD_PCR_R             Importance: 0.00246
# Variable: MD_CP                Importance: 0.00245
# Variable: MD_PLIC_L            Importance: 0.00244
# Variable: AD_ICP               Importance: 0.00242
# Variable: FA_CGC_R             Importance: 0.00242
# Variable: MD_ICP               Importance: 0.00241
# Variable: MD_CGC               Importance: 0.0024
# Variable: RD_EC_R              Importance: 0.00239
# Variable: RD_CP                Importance: 0.00238
# Variable: MD_EC_L              Importance: 0.00231
# Variable: MD_SFO_L             Importance: 0.00229
# Variable: RD_TAP               Importance: 0.00229
# Variable: MD_SFO_R             Importance: 0.00228
# Variable: RD_ALIC_L            Importance: 0.00228
# Variable: MD_PTR_R             Importance: 0.00227
# Variable: MD_EC_R              Importance: 0.00227
# Variable: MD_TAP               Importance: 0.00227
# Variable: AD_PLIC              Importance: 0.00226
# Variable: RD_PTR_R             Importance: 0.00226
# Variable: RD_IC                Importance: 0.00225
# Variable: RD_ALIC              Importance: 0.00223
# Variable: MD_SLF_R             Importance: 0.00219
# Variable: MD_RLIC              Importance: 0.00219
# Variable: RD_ACR_R             Importance: 0.00218
# Variable: RD_SCR               Importance: 0.00216
# Variable: AD_ALIC              Importance: 0.00215
# Variable: FA_ALIC_L            Importance: 0.00215
# Variable: MD_SS                Importance: 0.00215
# Variable: RD_PLIC              Importance: 0.00215
# Variable: MD_SCR_R             Importance: 0.00214
# Variable: RD_SLF               Importance: 0.00212
# Variable: MD_PLIC              Importance: 0.00211
# Variable: MD_ACR_L             Importance: 0.00209
# Variable: FA_ALIC              Importance: 0.00207
# Variable: FA_FULLWM            Importance: 0.00207
# Variable: RD_CGC               Importance: 0.00207
# Variable: FA_CGC               Importance: 0.00206
# Variable: RD_FULLWM            Importance: 0.00205
# Variable: RD_SFO_L             Importance: 0.00203
# Variable: RD_ACR_L             Importance: 0.00202
# Variable: RD_PTR               Importance: 0.00202
# Variable: RD_PCR               Importance: 0.00201
# Variable: MD_ACR_R             Importance: 0.00199
# Variable: MD_IC                Importance: 0.00199
# Variable: RD_EC_L              Importance: 0.00199
# Variable: MD_EC                Importance: 0.00196
# Variable: MD_PCR               Importance: 0.00194
# Variable: MD_PCR_R             Importance: 0.00193
# Variable: RD_EC                Importance: 0.00187
# Variable: AD_PCR               Importance: 0.00186
# Variable: AD_IC                Importance: 0.00185
# Variable: AD_FULLWM            Importance: 0.00184
# Variable: FA_IC                Importance: 0.00184
# Variable: FA_EC                Importance: 0.00182
# Variable: RD_CR                Importance: 0.0018
# Variable: RD_ACR               Importance: 0.00179
# Variable: RD_SFO               Importance: 0.00179
# Variable: MD_SCR_L             Importance: 0.00175
# Variable: MD_PTR               Importance: 0.0017
# Variable: MD_SCR               Importance: 0.00169
# Variable: MD_SFO               Importance: 0.00158
# Variable: MD_FULLWM            Importance: 0.00149
# Variable: MD_ACR               Importance: 0.00143
# Variable: MD_CR                Importance: 0.00139
# Variable: VOLUMES              Importance: 0.00098
# Variable: Sex_F                Importance: 0.00065
# Variable: Sex_M                Importance: 0.0006

# %%
# %matplotlib inline

plt.style.use('fivethirtyeight')

# list of x locations for plotting
x_values = list(range(len(importances)))

# make a bar chart
plt.bar(x_values, importances, orientation = 'vertical')

# tick labels for x axis
plt.xticks(x_values, feature_list, rotation='vertical')

# axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');
